# %% [markdown]
# #### Question 1
#
# ##### Calculate and write the output of the following expression:
# **30 + 4 × 3 − 6**

# %%
print(30+4*3-6)   # Python evaluates expressions
# Out:
# 36

# %% [markdown]
# #### Question 2
#
# ##### Calculate and write the output of the following expression:
# **100 ÷ 4 + 7 − 5**

# %%
print(100//4+7-5)   # Python evaluates expressions
# Out:
# 27

# %% [markdown]
# #### Question 3
#
# ##### Create a variable containing the string value "100". Convert it into an integer and display its data type before and after conversion.

# %%
x="100"

# %%
type(x)
# Out:
# str

# %%
x=int(x)   # converstion of string to integar

# %%
type(x)
# Out:
# int

# %% [markdown]
# #### Question 4
#
# ##### Create the following list and display:
# ##### cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]
# ##### Second city
# ##### Fourth city

# %%
cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]

# %%
print(cities[1])  # second city
# Out:
# Lahore

# %%
print(cities[3])  # fourth city
# Out:
# Peshawar

# %% [markdown]
# #### Question 5
# ##### Create the following nested list and display:
# ##### students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# ##### Ali
# ##### Ayesha

# %%
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]

# %%
print(students[0][0])
# Out:
# Ali

# %%
print(students[1][0])
# Out:
# Ayesha

# %% [markdown]
# #### Question 6
# ##### Given list:
# ##### numbers = [10, 20, 30, 40, 50, 60, 70]
# ##### Display:
# ##### First 3 elements
# ##### Last 3 elements

# %%
numbers = [10, 20, 30, 40, 50, 60, 70]

# %%
print(numbers[0:3])
# Out:
# [10, 20, 30]

# %%
print(numbers[-3:])
# Out:
# [50, 60, 70]

# %% [markdown]
# #### Question 7
# ##### Given nested list::
# ##### students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# ##### Display:
# ##### Name of first student
# ##### Age of second student

# %%
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]

# %%
print(students[0][0])
# Out:
# Ali

# %%
print(students[1][1])
# Out:
# 22

# %% [markdown]
# #### Question 8
# ##### Create a list of 5 fruits and display:
# ##### First fruit
# ##### Last fruit

# %%
fruits = ["apple", "orange", "mango", "cherry", "lychee"]

# %%
print(fruits[0])
# Out:
# apple

# %%
print(fruits[4])
# Out:
# lychee

# %% [markdown]
# #### Question 9
# ##### Create the following list and display:
# ##### colors = ["Red", "Blue", "Green", "Yellow", "Black"]
# ##### First color
# ##### Last color
# ##### using negative indexing

# %%
colors = ["Red", "Blue", "Green", "Yellow", "Black"]

# %%
print(colors[-5])
# Out:
# Red

# %%
print(colors[-1])
# Out:
# Black

# %% [markdown]
# #### Question 10
# ##### Given nested list:
# ##### marks = [["Math", 90], ["Physics", 85], ["English", 88]]
# ##### Display:
# ##### Subject of second student
# ##### Marks of third student

# %%
marks = [["Math", 90], ["Physics", 85], ["English", 88]]

# %%
print(marks[1][0])
# Out:
# Physics

# %%
print(marks[2][1])
# Out:
# 88
