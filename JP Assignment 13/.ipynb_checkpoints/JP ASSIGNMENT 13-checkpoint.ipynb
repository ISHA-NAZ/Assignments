# %% [markdown]
# ## Project: Ecommerce Sales Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("ecommerce_dataset - ecommerce_dataset.csv")
df
# Out:
#      order_id     product     category     price  quantity payment_method  \
# 0           1       Watch  Electronics  12652.30         4      Easypaisa
# 1           2         Bag      Fashion  20053.64         2    Credit Card
# 2           3       Shoes      Fashion  13274.17         2       JazzCash
# 3           4         Bag  Electronics  15332.08         1            COD
# 4           5         Bag  Accessories  23165.07         1     Debit Card
# ..        ...         ...          ...       ...       ...            ...
# 501         4         Bag  Electronics  15332.08         1            COD
# 502        18  Headphones  Electronics  14085.56         2     Debit Card
# 503        19      Laptop  Accessories  53657.14         4     Debit Card
# 504        20       Watch      Fashion  74385.39         4    Credit Card
# 505        21         Bag  Electronics  44762.65         4            COD
#
#            date      total    Month  Discount  City Code  Order Priority Code  \
# ...

# %%
df.dtypes   # types of data
# Out:
# order_id                 int64
# product                 object
# category                object
# price                  float64
# quantity                 int64
# payment_method          object
# date                    object
# total                  float64
# Month                   object
# Discount               float64
# City Code              float64
# Order Priority Code    float64
# Latitude               float64
# Longtitude             float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_id             506 non-null    int64
#  1   product              506 non-null    object
#  2   category             506 non-null    object
#  3   price                506 non-null    float64
#  4   quantity             506 non-null    int64
#  5   payment_method       506 non-null    object
#  6   date                 506 non-null    object
#  7   total                506 non-null    float64
#  8   Month                506 non-null    object
#  9   Discount             506 non-null    float64
#  10  City Code            491 non-null    float64
#  11  Order Priority Code  487 non-null    float64
#  12  Latitude             506 non-null    float64
#  13  Longtitude           506 non-null    float64
# dtypes: float64(7), int64(2), object(5)
# memory usage: 55.5+ KB

# %%
df.drop(columns=["Latitude", "Longtitude"], inplace=True)  # Drop irrelevant columns (Latitude, Longitude)

# %%
df.head()
# Out:
#    order_id product     category     price  quantity payment_method  \
# 0         1   Watch  Electronics  12652.30         4      Easypaisa
# 1         2     Bag      Fashion  20053.64         2    Credit Card
# 2         3   Shoes      Fashion  13274.17         2       JazzCash
# 3         4     Bag  Electronics  15332.08         1            COD
# 4         5     Bag  Accessories  23165.07         1     Debit Card
#
#          date     total    Month  Discount  City Code  Order Priority Code
# 0  01/01/2023  50609.20  January       0.0        1.0                  2.0
# 1  02/01/2023  40107.28  January       0.1        1.0                  2.0
# 2  03/01/2023  26548.34  January       0.1        1.0                  2.0
# 3  04/01/2023  15332.08  January       0.1        1.0                  2.0
# 4  05/01/2023  23165.07  January       0.0        1.0                  NaN

# %%
df.rename(columns={
    "City Code": "City",
    "Order Priority Code": "Order Priority"
}, inplace=True)                                # Rename columns City Code to City & Order Priority Code to Order Priority

# %%
df.columns
# Out:
# Index(['order_id', 'product', 'category', 'price', 'quantity',
#        'payment_method', 'date', 'total', 'Month', 'Discount', 'City',
#        'Order Priority'],
#       dtype='object')

# %%
df.duplicated().sum()   # Check duplicate rows
# Out:
# np.int64(6)

# %%
df[df.duplicated()]
# Out:
#      order_id     product     category     price  quantity payment_method  \
# 500         3       Shoes      Fashion  13274.17         2       JazzCash
# 501         4         Bag  Electronics  15332.08         1            COD
# 502        18  Headphones  Electronics  14085.56         2     Debit Card
# 503        19      Laptop  Accessories  53657.14         4     Debit Card
# 504        20       Watch      Fashion  74385.39         4    Credit Card
# 505        21         Bag  Electronics  44762.65         4            COD
#
#            date      total    Month  Discount  City  Order Priority
# 500  03/01/2023   26548.34  January       0.1   1.0             2.0
# 501  04/01/2023   15332.08  January       0.1   1.0             2.0
# 502  18/01/2023   28171.12  January       0.0   1.0             2.0
# 503  19/01/2023  214628.56  January       0.1   1.0             2.0
# 504  20/01/2023  297541.56  January       0.0   1.0             2.0
# ...

# %%
df.drop_duplicates(inplace=True)  # Drop duplicate records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()   # Check missing and null values
# Out:
# order_id           0
# product            0
# category           0
# price              0
# quantity           0
# payment_method     0
# date               0
# total              0
# Month              0
# Discount           0
# City              15
# Order Priority    19
# dtype: int64

# %%
df["total"].median()    # Fill missing sales value by their median
# Out:
# 78100.345

# %%
df["total"].fillna(df["total"].median(), inplace=True)

# %%
df["total"].isnull().sum()
# Out:
# np.int64(0)

# %%
top_products = (
    df.groupby("product")["total"]
    .sum()
    .sort_values(ascending=False)
    .head(5)
)

top_products
# Out:
# product
# Headphones    9414259.95
# Watch         9295181.97
# Mobile        8478520.28
# Shoes         8304435.17
# Laptop        7908062.14
# Name: total, dtype: float64

# %%
plt.figure(figsize=(10, 6))

sns.barplot(
    x=top_products.values,
    y=top_products.index
)

plt.title("Top 5 Best Selling Products")
plt.xlabel("Total Sales")
plt.ylabel("Product")

plt.show()      # Top 5 Best Selling Products

# %%
payment_counts = df["payment_method"].value_counts()

payment_counts
# Out:
# payment_method
# JazzCash       112
# Credit Card    107
# Easypaisa      105
# COD             97
# Debit Card      79
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))

plt.pie(
    payment_counts.values,
    labels=payment_counts.index,
    autopct="%1.1f%%"
)

plt.title("Payment Method Distribution")

plt.show()      # Payment Method Distribution

# %%
monthly_sales = df.groupby("Month")["total"].sum()
monthly_sales
# Out:
# Month
# April        6275753.74
# August       2557288.54
# December     3952563.75
# February     5545040.22
# January      6238414.59
# July         2688475.62
# June         2860920.11
# March        6711119.66
# May          5909845.92
# November     2805153.37
# October      3139444.82
# September    2515916.08
# Name: total, dtype: float64

# %%
month_order = [
    "January",
    "February",
    "March",
    "April",
    "May",
    "June",
    "July",
    "August",
    "September",
    "October",
    "November",
    "December"
]

monthly_sales = (
    df.groupby("Month")["total"]
    .sum()
    .reindex(month_order)
)

monthly_sales
# Out:
# Month
# January      6238414.59
# February     5545040.22
# March        6711119.66
# April        6275753.74
# May          5909845.92
# June         2860920.11
# July         2688475.62
# August       2557288.54
# September    2515916.08
# October      3139444.82
# November     2805153.37
# December     3952563.75
# Name: total, dtype: float64

# %%
plt.figure(figsize=(12, 6))

plt.plot(
    monthly_sales.index,
    monthly_sales.values,
    marker="o"
)

plt.title("Month-wise Sales")
plt.xlabel("Month")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)

plt.show()       # Month-wise Sales

# %%
city_mapping = {
    1: "Karachi",
    2: "Lahore",
    3: "Islamabad",
    4: "Faisalabad",
    5: "Quetta",
    6: "Peshawar"
}

df["City"] = df["City"].map(city_mapping)

# %%
df["City"].value_counts()
# Out:
# City
# Lahore        140
# Quetta         97
# Islamabad      77
# Peshawar       71
# Faisalabad     52
# Karachi        48
# Name: count, dtype: int64

# %%
city_sales = (
    df.groupby("City")["total"]
    .sum()
    .sort_values(ascending=True)
)

city_sales
# Out:
# City
# Karachi        5060916.14
# Peshawar       6194016.19
# Faisalabad     6318998.97
# Islamabad      8028811.58
# Quetta         9488620.43
# Lahore        14665005.16
# Name: total, dtype: float64

# %%
plt.figure(figsize=(10, 6))

sns.barplot(
    x=city_sales.values,
    y=city_sales.index
)

plt.title("City-wise Sales")
plt.xlabel("Total Sales")
plt.ylabel("City")

plt.show()      # Show City wise sales

# %%
monthly_category_sales = df.pivot_table(
    index="Month",
    columns="category",
    values="total",
    aggfunc="sum"
)

monthly_category_sales = monthly_category_sales.reindex(month_order)

monthly_category_sales
# Out:
# category   Accessories  Electronics     Fashion
# Month
# January     2745729.82   1855039.15  1637645.62
# February    1178881.69   1929360.80  2436797.73
# March       2749630.71   2457415.74  1504073.21
# April       2387980.38   2265079.20  1622694.16
# May         1240740.21   2352232.89  2316872.82
# June        1421673.13    657353.10   781893.88
# July         961408.72   1218489.97   508576.93
# August       521529.94    881950.11  1153808.49
# September    849152.91    952931.97   713831.20
# October      496080.70   1911295.72   732068.40
# November     739060.88    991960.56  1074131.93
# December    1005459.07   1460885.05  1486219.63

# %%
monthly_category_sales.plot(
    kind="bar",
    figsize=(14, 7)
)

plt.title("Monthly Sales by Category")
plt.xlabel("Month")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)

plt.legend(title="Category")

plt.show()     # Show monthly Sales by Category
